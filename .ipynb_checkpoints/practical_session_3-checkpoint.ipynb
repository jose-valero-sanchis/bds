# %% [markdown]
# <h1 style="text-align:center;">Practical session 3</h1>
# <h2 style="text-align:center;">Biomedical Data Science</h2>
# <h3 style="text-align:center;">Lucas Fayolle & Jose Valero</h3>

# %% [markdown]
# # Block 0. Libraries

# %%
import tensorflow as tf
tf.get_logger().setLevel('ERROR')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import f1_score
import itertools
from sklearn.metrics import classification_report
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_recall_fscore_support, roc_auc_score
from sklearn.preprocessing import label_binarize

# %% [markdown]
# # Block I. Data preparation

# %% [markdown]
# ## 1. Load your data and extract basic data descriptors using the pandas profiling package

# %% [markdown]
# ### 1.1 Load Data

# %%
df = pd.read_csv("Metabolite_concentrations_diagnosis.csv", sep = ";", usecols=range(1,17))

metabolite_columns = df.columns[df.columns != 'TYPE']
df[metabolite_columns] = df[metabolite_columns].apply(lambda x: x.str.replace(',', '.').astype(float))

df
# Out:
#     METABOLITE 0  METABOLITE 1  METABOLITE 2  METABOLITE 3  METABOLITE 4  \
# 0       0.322695      0.575024      0.742645      0.635958      0.544804
# 1       0.457408      0.764700      0.444451      0.451300      0.388213
# 2       1.452870      1.152910      0.647735      0.622494      0.648020
# 3       0.157588      0.314415      0.251613      0.186498      0.100556
# 4       0.368681      0.206993      0.211521      0.034699      0.164187
# ..           ...           ...           ...           ...           ...
# 86      1.146621      1.952639      1.240700      1.216044      0.873140
# 87      1.304585      1.048878      1.456252      1.391773      0.716365
# 88      1.648198      1.965646      0.913688      0.925384      1.040036
# 89      0.524946      0.711819      0.459294      0.450123      0.532891
# 90      1.162867      2.197796      0.933719      0.903978      0.862433
#
#     METABOLITE 5  METABOLITE 6  METABOLITE 7  METABOLITE 8  METABOLITE 9  \
# 0       0.785336      0.885756      0.577938      0.123017      0.701689
# 1       0.401597      0.382574      0.407632      0.715072      1.216084
# 2       0.826787      0.797439      0.695269      0.850328      0.910488
# 3       0.287618      0.334349      0.213802      0.305852      0.754096
# 4       0.364590      0.340892      0.110287      0.260206      0.531801
# ..           ...           ...           ...           ...           ...
# 86      1.341280      1.344396      0.566293      0.714166      2.140718
# 87      1.224394      1.465654      1.349410      0.868388      2.699551
# 88      1.344963      1.313133      0.635587      0.974705      1.477950
# 89      0.464126      0.539442      0.431146      0.263541      1.087815
# 90      2.357651      2.443410      0.568944      1.010334      1.096059
#
#     METABOLITE 10  METABOLITE 11  METABOLITE 12  METABOLITE 13  METABOLITE 14  \
# 0        0.731254       0.846980       3.551957       3.742832       1.719949
# 1        1.204490       2.329079       3.179366       3.117351       1.252479
# 2        0.914841       1.805095       2.156737       2.152553       1.081571
# 3        0.627211       1.566407       4.274654       4.210731       1.128131
# 4        0.496068       0.654805       4.070067       4.324002       1.350580
# ..            ...            ...            ...            ...            ...
# 86       2.027257       0.735564       0.975908       1.080736       0.984968
# 87       2.731945       0.795505       0.725981       0.700257       0.622597
# 88       1.421918       0.643054       1.233130       1.254060       1.052289
# 89       1.003663       0.888594       2.263318       2.392848       2.219673
# 90       1.055041       0.912258       0.862538       0.751915       0.636022
#
#             TYPE
# 0     MENINGIOMA
# 1     MENINGIOMA
# 2     MENINGIOMA
# 3     MENINGIOMA
# 4     MENINGIOMA
# ..           ...
# 86  GLIOBLASTOMA
# 87  GLIOBLASTOMA
# 88  GLIOBLASTOMA
# 89  GLIOBLASTOMA
# 90  GLIOBLASTOMA
#
# [91 rows x 16 columns]

# %% [markdown]
# ### 1.2 Exploratory analysis

# %%
# profile = ProfileReport(df, title='Metabolite Concentrations Diagnosis Report')
# profile.to_file('metabolite_profile_report.html')

# %% [markdown]
# Some important things for later sections that are worth extracting from the report:
#
# - En los metabolitos hay algunos valores extremos que hay que eliminar
# - No hay valores faltantes, por lo tanto ningun metodo de imputación debe ser utilziado
# - La correlación entre las variables es la siguiente:
#
# ![image-3.png](attachment:image-3.png)
#
# - Hay un desbalanceo en la variable objetivo que puede ser importante
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 2. Create an auxiliary one hot encoded variable for each of the 3 types of brain tumors.

# %%
df['TYPE_ORG'] = df['TYPE']
df = pd.get_dummies(df, columns=['TYPE'])
df
# Out:
#     METABOLITE 0  METABOLITE 1  METABOLITE 2  METABOLITE 3  METABOLITE 4  \
# 0       0.322695      0.575024      0.742645      0.635958      0.544804
# 1       0.457408      0.764700      0.444451      0.451300      0.388213
# 2       1.452870      1.152910      0.647735      0.622494      0.648020
# 3       0.157588      0.314415      0.251613      0.186498      0.100556
# 4       0.368681      0.206993      0.211521      0.034699      0.164187
# ..           ...           ...           ...           ...           ...
# 86      1.146621      1.952639      1.240700      1.216044      0.873140
# 87      1.304585      1.048878      1.456252      1.391773      0.716365
# 88      1.648198      1.965646      0.913688      0.925384      1.040036
# 89      0.524946      0.711819      0.459294      0.450123      0.532891
# 90      1.162867      2.197796      0.933719      0.903978      0.862433
#
#     METABOLITE 5  METABOLITE 6  METABOLITE 7  METABOLITE 8  METABOLITE 9  \
# 0       0.785336      0.885756      0.577938      0.123017      0.701689
# 1       0.401597      0.382574      0.407632      0.715072      1.216084
# 2       0.826787      0.797439      0.695269      0.850328      0.910488
# 3       0.287618      0.334349      0.213802      0.305852      0.754096
# 4       0.364590      0.340892      0.110287      0.260206      0.531801
# ..           ...           ...           ...           ...           ...
# 86      1.341280      1.344396      0.566293      0.714166      2.140718
# 87      1.224394      1.465654      1.349410      0.868388      2.699551
# 88      1.344963      1.313133      0.635587      0.974705      1.477950
# 89      0.464126      0.539442      0.431146      0.263541      1.087815
# 90      2.357651      2.443410      0.568944      1.010334      1.096059
#
#     METABOLITE 10  METABOLITE 11  METABOLITE 12  METABOLITE 13  METABOLITE 14  \
# 0        0.731254       0.846980       3.551957       3.742832       1.719949
# 1        1.204490       2.329079       3.179366       3.117351       1.252479
# 2        0.914841       1.805095       2.156737       2.152553       1.081571
# 3        0.627211       1.566407       4.274654       4.210731       1.128131
# 4        0.496068       0.654805       4.070067       4.324002       1.350580
# ..            ...            ...            ...            ...            ...
# 86       2.027257       0.735564       0.975908       1.080736       0.984968
# 87       2.731945       0.795505       0.725981       0.700257       0.622597
# 88       1.421918       0.643054       1.233130       1.254060       1.052289
# 89       1.003663       0.888594       2.263318       2.392848       2.219673
# 90       1.055041       0.912258       0.862538       0.751915       0.636022
#
#         TYPE_ORG  TYPE_ASTROCYTOMA  TYPE_GLIOBLASTOMA  TYPE_MENINGIOMA
# 0     MENINGIOMA             False              False             True
# 1     MENINGIOMA             False              False             True
# 2     MENINGIOMA             False              False             True
# 3     MENINGIOMA             False              False             True
# 4     MENINGIOMA             False              False             True
# ..           ...               ...                ...              ...
# 86  GLIOBLASTOMA             False               True            False
# 87  GLIOBLASTOMA             False               True            False
# 88  GLIOBLASTOMA             False               True            False
# 89  GLIOBLASTOMA             False               True            False
# 90  GLIOBLASTOMA             False               True            False
#
# [91 rows x 19 columns]

# %% [markdown]
# ## 3. Split your data using a holdout methodology considering odds of 70:30

# %%
train_df, test_df = train_test_split(df, test_size=0.3, random_state=23, stratify=df['TYPE_ORG'])

# %% [markdown]
# ## 4. Perform robust scaling on each of the datasets generated in 3)

# %%
exclude_cols = ['TYPE_ORG'] + [col for col in train_df.columns if col.startswith('TYPE_')]
numeric_cols = [col for col in train_df.columns if col not in exclude_cols]

scaler = RobustScaler(quantile_range=(2.5, 97.5))

scaler.fit(train_df[numeric_cols])

train_df_scaled = train_df.copy()
test_df_scaled = test_df.copy()

train_df_scaled[numeric_cols] = scaler.transform(train_df[numeric_cols])
test_df_scaled[numeric_cols] = scaler.transform(test_df[numeric_cols])

# %%
X_train = train_df_scaled.drop(columns=['TYPE_ORG', 'TYPE_ASTROCYTOMA', 'TYPE_GLIOBLASTOMA', 'TYPE_MENINGIOMA'])
X_test = test_df_scaled.drop(columns=['TYPE_ORG', 'TYPE_ASTROCYTOMA', 'TYPE_GLIOBLASTOMA', 'TYPE_MENINGIOMA'])

y_train = train_df_scaled[['TYPE_ASTROCYTOMA', 'TYPE_GLIOBLASTOMA', 'TYPE_MENINGIOMA']]
y_test = test_df_scaled[['TYPE_ASTROCYTOMA', 'TYPE_GLIOBLASTOMA', 'TYPE_MENINGIOMA']]

# %% [markdown]
# # Block II. Model training and selection

# %% [markdown]
# ## 1. Choose a proper evaluation metric suitable for the problem

# %% [markdown]
# Clases desbalanceadas: La distribución de las clases es la siguiente:
# - MENINGIOMA: 52 muestras
# - ASTROCYTOMA: 23 muestras
# - GLIOBLASTOMA: 16 muestras

# %% [markdown]
# Dado que necesitamos una métrica que no esté sesgada por el desbalance de clases y que trate a todas las clases de manera equitativa, el F1-Score Macro Promediado es una opción adecuada. Esta métrica:
#
# - Da igual importancia a todas las clases, independientemente del número de muestras.
# - Combina precisión y recall, proporcionando una visión equilibrada del rendimiento del modelo.

# %% [markdown]
# ## 2. Run some experiments:

# %%
def create_model(learning_rate=0.001, architecture=[64, 32], input_dim=None):
    model = Sequential()

    for idx, units in enumerate(architecture):
        if idx == 0:
            model.add(Dense(units, input_dim=input_dim, activation='relu'))
        else:
            model.add(Dense(units, activation='relu'))

    model.add(Dense(3, activation='softmax'))
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy')
    return model

# %%
def train_and_evaluate_model(model, X_train, y_train, X_test, y_test, batch_size=32, epochs=10):
    model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=0)
    y_pred_prob = model.predict(X_test)
    y_pred = np.argmax(y_pred_prob, axis=1)
    y_true = np.argmax(y_test, axis=1)
    f1_macro = f1_score(y_true, y_pred, average='macro')
    return f1_macro

# %% [markdown]
# ### 2.1 Learning rate

# %%
learning_rates = [0.00001, 0.0001, 0.001, 0.01, 0.1]
results_lr = []

input_dim = X_train.shape[1]

for lr in learning_rates:
    model = create_model(learning_rate=lr, input_dim=input_dim)
    f1_macro = train_and_evaluate_model(model, X_train, y_train, X_test, y_test)
    results_lr.append({'learning_rate': lr, 'f1_macro': f1_macro})
    print(f"Learning rate: {lr}, F1 Macro Score: {f1_macro:.4f}")
# Out:
# 1/1 [==============================] - 0s 89ms/step
# Learning rate: 1e-05, F1 Macro Score: 0.4444
# 1/1 [==============================] - 0s 87ms/step
# Learning rate: 0.0001, F1 Macro Score: 0.3195
# 1/1 [==============================] - 0s 50ms/step
# Learning rate: 0.001, F1 Macro Score: 0.5051
# 1/1 [==============================] - 0s 43ms/step
# Learning rate: 0.01, F1 Macro Score: 0.8755
# 1/1 [==============================] - 0s 72ms/step
# Learning rate: 0.1, F1 Macro Score: 0.8172

# %%
df_lr = pd.DataFrame(results_lr)
plt.figure()
plt.plot(df_lr['learning_rate'], df_lr['f1_macro'], marker='o')
plt.xscale('log')
plt.xlabel('Tasa de Aprendizaje')
plt.ylabel('F1 Macro Score')
plt.title('Influencia de la Tasa de Aprendizaje')
plt.show()

# %% [markdown]
# ### 2.2 Batch size

# %%
batch_sizes = [8, 16, 32, 64, 128]
results_bs = []

for bs in batch_sizes:
    model = create_model(learning_rate=0.001, input_dim=input_dim)
    f1_macro = train_and_evaluate_model(model, X_train, y_train, X_test, y_test, batch_size=bs)
    results_bs.append({'batch_size': bs, 'f1_macro': f1_macro})
    print(f"Batch size: {bs}, F1 Macro Score: {f1_macro:.4f}")
# Out:
# 1/1 [==============================] - 0s 57ms/step
# Batch size: 8, F1 Macro Score: 0.6494
# 1/1 [==============================] - 0s 80ms/step
# Batch size: 16, F1 Macro Score: 0.4607
# 1/1 [==============================] - 0s 70ms/step
# Batch size: 32, F1 Macro Score: 0.5011
# 1/1 [==============================] - 0s 59ms/step
# Batch size: 64, F1 Macro Score: 0.5011
# 1/1 [==============================] - 0s 87ms/step
# Batch size: 128, F1 Macro Score: 0.5051

# %%
df_bs = pd.DataFrame(results_bs)
plt.figure()
plt.plot(df_bs['batch_size'], df_bs['f1_macro'], marker='o')
plt.xlabel('Tamaño de Lote')
plt.ylabel('F1 Macro Score')
plt.title('Influencia del Tamaño de Lote')
plt.show()

# %% [markdown]
# ### 2.3 Architecture

# %%
architectures = [
    [32],
    [64],
    [128],
    [64, 32],
    [128, 64, 32],
    [256, 128, 64],
    [64, 64, 32],
    [128, 64, 16]
]
results_arch = []

for arch in architectures:
    model = create_model(learning_rate=0.001, architecture=arch, input_dim=input_dim)
    f1_macro = train_and_evaluate_model(model, X_train, y_train, X_test, y_test)
    results_arch.append({'architecture': arch, 'f1_macro': f1_macro})
    arch_str = '-'.join(map(str, arch))
    print(f"Architecture: {arch_str}, F1 Macro Score: {f1_macro:.4f}")
# Out:
# 1/1 [==============================] - 0s 65ms/step
# Architecture: 32, F1 Macro Score: 0.4789
# 1/1 [==============================] - 0s 55ms/step
# Architecture: 64, F1 Macro Score: 0.5230
# 1/1 [==============================] - 0s 67ms/step
# Architecture: 128, F1 Macro Score: 0.5011
# 1/1 [==============================] - 0s 60ms/step
# Architecture: 64-32, F1 Macro Score: 0.4889
# 1/1 [==============================] - 0s 82ms/step
# Architecture: 128-64-32, F1 Macro Score: 0.4940
# 1/1 [==============================] - 0s 55ms/step
# Architecture: 256-128-64, F1 Macro Score: 0.4940
# 1/1 [==============================] - 0s 58ms/step
# Architecture: 64-64-32, F1 Macro Score: 0.5051
# 1/1 [==============================] - 0s 85ms/step
# Architecture: 128-64-16, F1 Macro Score: 0.5051

# %%
df_arch = pd.DataFrame(results_arch)
df_arch['architecture_str'] = df_arch['architecture'].apply(lambda x: '-'.join(map(str, x)))

plt.figure()
plt.bar(df_arch['architecture_str'], df_arch['f1_macro'])
plt.xlabel('Arquitectura')
plt.ylabel('F1 Macro Score')
plt.title('Influencia de la Arquitectura')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 2.4 Number iterations

# %%
epochs_list = [10, 50, 100, 200]
results_epochs = []

for epochs in epochs_list:
    model = create_model(learning_rate=0.001, input_dim=input_dim)
    f1_macro = train_and_evaluate_model(model, X_train, y_train, X_test, y_test, epochs=epochs)
    results_epochs.append({'epochs': epochs, 'f1_macro': f1_macro})
    print(f"Epochs: {epochs}, F1 Macro Score: {f1_macro:.4f}")
# Out:
# 1/1 [==============================] - 0s 73ms/step
# Epochs: 10, F1 Macro Score: 0.6000
# 1/1 [==============================] - 0s 48ms/step
# Epochs: 50, F1 Macro Score: 0.7383
# 1/1 [==============================] - 0s 48ms/step
# Epochs: 100, F1 Macro Score: 0.8755
# 1/1 [==============================] - 0s 54ms/step
# Epochs: 200, F1 Macro Score: 0.8374

# %%
df_epochs = pd.DataFrame(results_epochs)
plt.figure()
plt.plot(df_epochs['epochs'], df_epochs['f1_macro'], marker='o')
plt.xlabel('Número de Épocas')
plt.ylabel('F1 Macro Score')
plt.title('Influencia del Número de Épocas')
plt.show()

# %% [markdown]
# ## 3. Select the best hyperparams configuration

# %%
def train_and_evaluate_model(learning_rate, batch_size, architecture, epochs, input_dim, X_train, y_train, X_test, y_test):
    # Crear el modelo con los hiperparámetros especificados
    model = create_model(learning_rate=learning_rate, architecture=architecture, input_dim=input_dim)
    # Entrenar el modelo
    model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=0)
    # Realizar predicciones en el conjunto de prueba
    y_pred_prob = model.predict(X_test)
    y_pred = np.argmax(y_pred_prob, axis=1)
    y_true = np.argmax(y_test, axis=1)
    # Calcular el F1 Macro Score
    f1_macro = f1_score(y_true, y_pred, average='macro')
    return f1_macro

# %%
learning_rates = [0.00001, 0.0001, 0.001, 0.01, 0.1]
batch_sizes = [8, 16, 32, 64, 128]
architectures = [
    [32],
    [64],
    [128],
    [64, 32],
    [128, 64, 32],
    [256, 128, 64],
    [64, 64, 32],
    [128, 64, 16]
]
epochs_list = [10, 50, 100, 200]

param_grid = list(itertools.product(learning_rates, batch_sizes, architectures, epochs_list))

# %%
results = []

input_dim = X_train.shape[1]

# Iterar sobre todas las combinaciones de hiperparámetros
for lr, bs, arch, ep in param_grid:
    f1_macro = train_and_evaluate_model(
        learning_rate=lr,
        batch_size=bs,
        architecture=arch,
        epochs=ep,
        input_dim=input_dim,
        X_train=X_train,
        y_train=y_train,
        X_test=X_test,
        y_test=y_test
    )
    # Registrar el resultado
    results.append({
        'learning_rate': lr,
        'batch_size': bs,
        'architecture': arch,
        'epochs': ep,
        'f1_macro': f1_macro
    })
    print(f"Tasa de aprendizaje: {lr}, Tamaño de lote: {bs}, Arquitectura: {arch}, Epochs: {ep}, F1 Macro: {f1_macro:.4f}")
# Out:
# 1/1 [==============================] - 0s 71ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [32], Epochs: 10, F1 Macro: 0.2462
# 1/1 [==============================] - 0s 74ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [32], Epochs: 50, F1 Macro: 0.2295
# 1/1 [==============================] - 0s 76ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [32], Epochs: 100, F1 Macro: 0.1739
# 1/1 [==============================] - 0s 70ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [32], Epochs: 200, F1 Macro: 0.2424
# 1/1 [==============================] - 0s 62ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [64], Epochs: 10, F1 Macro: 0.3907
# 1/1 [==============================] - 0s 55ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [64], Epochs: 50, F1 Macro: 0.3951
# 1/1 [==============================] - 0s 75ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [64], Epochs: 100, F1 Macro: 0.3846
# 1/1 [==============================] - 0s 60ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [64], Epochs: 200, F1 Macro: 0.4671
# 1/1 [==============================] - 0s 43ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [128], Epochs: 10, F1 Macro: 0.1568
# 1/1 [==============================] - 0s 69ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [128], Epochs: 50, F1 Macro: 0.1816
# 1/1 [==============================] - 0s 80ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [128], Epochs: 100, F1 Macro: 0.7089
# 1/1 [==============================] - 0s 103ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [128], Epochs: 200, F1 Macro: 0.5947
# 1/1 [==============================] - 0s 99ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [64, 32], Epochs: 10, F1 Macro: 0.4479
# 1/1 [==============================] - 0s 103ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [64, 32], Epochs: 50, F1 Macro: 0.4485
# 1/1 [==============================] - 0s 107ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [64, 32], Epochs: 100, F1 Macro: 0.5011
# 1/1 [==============================] - 0s 105ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [64, 32], Epochs: 200, F1 Macro: 0.3879
# 1/1 [==============================] - 0s 100ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [128, 64, 32], Epochs: 10, F1 Macro: 0.2467
# 1/1 [==============================] - 0s 126ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [128, 64, 32], Epochs: 50, F1 Macro: 0.6715
# 1/1 [==============================] - 0s 128ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [128, 64, 32], Epochs: 100, F1 Macro: 0.3592
# 1/1 [==============================] - 0s 119ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [128, 64, 32], Epochs: 200, F1 Macro: 0.2424
# 1/1 [==============================] - 0s 109ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [256, 128, 64], Epochs: 10, F1 Macro: 0.4644
# 1/1 [==============================] - 0s 95ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [256, 128, 64], Epochs: 50, F1 Macro: 0.6919
# 1/1 [==============================] - 0s 146ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [256, 128, 64], Epochs: 100, F1 Macro: 0.5513
# 1/1 [==============================] - 0s 109ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [256, 128, 64], Epochs: 200, F1 Macro: 0.6250
# 1/1 [==============================] - 0s 96ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [64, 64, 32], Epochs: 10, F1 Macro: 0.2326
# 1/1 [==============================] - 0s 85ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [64, 64, 32], Epochs: 50, F1 Macro: 0.4021
# 1/1 [==============================] - 0s 108ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [64, 64, 32], Epochs: 100, F1 Macro: 0.5561
# 1/1 [==============================] - 0s 139ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [64, 64, 32], Epochs: 200, F1 Macro: 0.4607
# 1/1 [==============================] - 0s 105ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [128, 64, 16], Epochs: 10, F1 Macro: 0.4091
# 1/1 [==============================] - 0s 108ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [128, 64, 16], Epochs: 50, F1 Macro: 0.3106
# 1/1 [==============================] - 0s 105ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [128, 64, 16], Epochs: 100, F1 Macro: 0.4131
# 1/1 [==============================] - 0s 117ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 8, Arquitectura: [128, 64, 16], Epochs: 200, F1 Macro: 0.6000
# 1/1 [==============================] - 0s 85ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [32], Epochs: 10, F1 Macro: 0.1296
# 1/1 [==============================] - 0s 101ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [32], Epochs: 50, F1 Macro: 0.2226
# 1/1 [==============================] - 0s 87ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [32], Epochs: 100, F1 Macro: 0.1587
# 1/1 [==============================] - 0s 94ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [32], Epochs: 200, F1 Macro: 0.1538
# 1/1 [==============================] - 0s 69ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [64], Epochs: 10, F1 Macro: 0.2829
# 1/1 [==============================] - 0s 82ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [64], Epochs: 50, F1 Macro: 0.3485
# 1/1 [==============================] - 0s 106ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [64], Epochs: 100, F1 Macro: 0.3923
# 1/1 [==============================] - 0s 84ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [64], Epochs: 200, F1 Macro: 0.4794
# 1/1 [==============================] - 0s 87ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [128], Epochs: 10, F1 Macro: 0.1503
# 1/1 [==============================] - 0s 77ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [128], Epochs: 50, F1 Macro: 0.5302
# 1/1 [==============================] - 0s 92ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [128], Epochs: 100, F1 Macro: 0.4818
# 1/1 [==============================] - 0s 85ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [128], Epochs: 200, F1 Macro: 0.4991
# 1/1 [==============================] - 0s 84ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [64, 32], Epochs: 10, F1 Macro: 0.2956
# 1/1 [==============================] - 0s 62ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [64, 32], Epochs: 50, F1 Macro: 0.4716
# 1/1 [==============================] - 0s 61ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [64, 32], Epochs: 100, F1 Macro: 0.4013
# 1/1 [==============================] - 0s 79ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [64, 32], Epochs: 200, F1 Macro: 0.5625
# 1/1 [==============================] - 0s 53ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [128, 64, 32], Epochs: 10, F1 Macro: 0.0733
# 1/1 [==============================] - 0s 84ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [128, 64, 32], Epochs: 50, F1 Macro: 0.7233
# 1/1 [==============================] - 0s 83ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [128, 64, 32], Epochs: 100, F1 Macro: 0.3592
# 1/1 [==============================] - 0s 92ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [128, 64, 32], Epochs: 200, F1 Macro: 0.4671
# 1/1 [==============================] - 0s 104ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [256, 128, 64], Epochs: 10, F1 Macro: 0.2424
# 1/1 [==============================] - 0s 79ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [256, 128, 64], Epochs: 50, F1 Macro: 0.4748
# 1/1 [==============================] - 0s 94ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [256, 128, 64], Epochs: 100, F1 Macro: 0.2424
# 1/1 [==============================] - 0s 122ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [256, 128, 64], Epochs: 200, F1 Macro: 0.4556
# 1/1 [==============================] - 0s 136ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [64, 64, 32], Epochs: 10, F1 Macro: 0.2424
# 1/1 [==============================] - 0s 125ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [64, 64, 32], Epochs: 50, F1 Macro: 0.3963
# 1/1 [==============================] - 0s 131ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [64, 64, 32], Epochs: 100, F1 Macro: 0.3314
# 1/1 [==============================] - 0s 93ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [64, 64, 32], Epochs: 200, F1 Macro: 0.4344
# 1/1 [==============================] - 0s 98ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [128, 64, 16], Epochs: 10, F1 Macro: 0.2325
# 1/1 [==============================] - 0s 97ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [128, 64, 16], Epochs: 50, F1 Macro: 0.2167
# 1/1 [==============================] - 0s 133ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [128, 64, 16], Epochs: 100, F1 Macro: 0.5937
# 1/1 [==============================] - 0s 155ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 16, Arquitectura: [128, 64, 16], Epochs: 200, F1 Macro: 0.7138
# 1/1 [==============================] - 0s 87ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [32], Epochs: 10, F1 Macro: 0.1800
# 1/1 [==============================] - 0s 78ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [32], Epochs: 50, F1 Macro: 0.2222
# 1/1 [==============================] - 0s 69ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [32], Epochs: 100, F1 Macro: 0.6155
# 1/1 [==============================] - 0s 54ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [32], Epochs: 200, F1 Macro: 0.4078
# 1/1 [==============================] - 0s 79ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [64], Epochs: 10, F1 Macro: 0.5079
# 1/1 [==============================] - 0s 55ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [64], Epochs: 50, F1 Macro: 0.4643
# 1/1 [==============================] - 0s 47ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [64], Epochs: 100, F1 Macro: 0.1684
# 1/1 [==============================] - 0s 48ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [64], Epochs: 200, F1 Macro: 0.3834
# 1/1 [==============================] - 0s 31ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [128], Epochs: 10, F1 Macro: 0.5442
# 1/1 [==============================] - 0s 63ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [128], Epochs: 50, F1 Macro: 0.1480
# 1/1 [==============================] - 0s 47ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [128], Epochs: 100, F1 Macro: 0.2215
# 1/1 [==============================] - 0s 63ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [128], Epochs: 200, F1 Macro: 0.4405
# 1/1 [==============================] - 0s 71ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [64, 32], Epochs: 10, F1 Macro: 0.1042
# 1/1 [==============================] - 0s 68ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [64, 32], Epochs: 50, F1 Macro: 0.3314
# 1/1 [==============================] - 0s 79ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [64, 32], Epochs: 100, F1 Macro: 0.0860
# 1/1 [==============================] - 0s 47ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [64, 32], Epochs: 200, F1 Macro: 0.3504
# 1/1 [==============================] - 0s 110ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [128, 64, 32], Epochs: 10, F1 Macro: 0.3163
# 1/1 [==============================] - 0s 50ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [128, 64, 32], Epochs: 50, F1 Macro: 0.1765
# 1/1 [==============================] - 0s 95ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [128, 64, 32], Epochs: 100, F1 Macro: 0.3268
# 1/1 [==============================] - 0s 64ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [128, 64, 32], Epochs: 200, F1 Macro: 0.5630
# 1/1 [==============================] - 0s 78ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [256, 128, 64], Epochs: 10, F1 Macro: 0.3214
# 1/1 [==============================] - 0s 127ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [256, 128, 64], Epochs: 50, F1 Macro: 0.5400
# 1/1 [==============================] - 0s 94ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [256, 128, 64], Epochs: 100, F1 Macro: 0.2424
# 1/1 [==============================] - 0s 78ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [256, 128, 64], Epochs: 200, F1 Macro: 0.2540
# 1/1 [==============================] - 0s 80ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [64, 64, 32], Epochs: 10, F1 Macro: 0.3053
# 1/1 [==============================] - 0s 94ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [64, 64, 32], Epochs: 50, F1 Macro: 0.2222
# 1/1 [==============================] - 0s 77ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [64, 64, 32], Epochs: 100, F1 Macro: 0.2326
# 1/1 [==============================] - 0s 102ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [64, 64, 32], Epochs: 200, F1 Macro: 0.4556
# 1/1 [==============================] - 0s 117ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [128, 64, 16], Epochs: 10, F1 Macro: 0.1042
# 1/1 [==============================] - 0s 106ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [128, 64, 16], Epochs: 50, F1 Macro: 0.4172
# 1/1 [==============================] - 0s 100ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [128, 64, 16], Epochs: 100, F1 Macro: 0.3696
# 1/1 [==============================] - 0s 87ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 32, Arquitectura: [128, 64, 16], Epochs: 200, F1 Macro: 0.4231
# 1/1 [==============================] - 0s 60ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [32], Epochs: 10, F1 Macro: 0.1765
# 1/1 [==============================] - 0s 77ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [32], Epochs: 50, F1 Macro: 0.3716
# 1/1 [==============================] - 0s 47ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [32], Epochs: 100, F1 Macro: 0.1333
# 1/1 [==============================] - 0s 63ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [32], Epochs: 200, F1 Macro: 0.1622
# 1/1 [==============================] - 0s 47ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [64], Epochs: 10, F1 Macro: 0.1739
# 1/1 [==============================] - 0s 63ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [64], Epochs: 50, F1 Macro: 0.1075
# 1/1 [==============================] - 0s 47ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [64], Epochs: 100, F1 Macro: 0.3900
# 1/1 [==============================] - 0s 63ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [64], Epochs: 200, F1 Macro: 0.2264
# 1/1 [==============================] - 0s 47ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [128], Epochs: 10, F1 Macro: 0.2131
# 1/1 [==============================] - 0s 79ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [128], Epochs: 50, F1 Macro: 0.1373
# 1/1 [==============================] - 0s 31ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [128], Epochs: 100, F1 Macro: 0.2839
# 1/1 [==============================] - 0s 79ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [128], Epochs: 200, F1 Macro: 0.2578
# 1/1 [==============================] - 0s 79ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [64, 32], Epochs: 10, F1 Macro: 0.1333
# 1/1 [==============================] - 0s 78ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [64, 32], Epochs: 50, F1 Macro: 0.1778
# 1/1 [==============================] - 0s 92ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [64, 32], Epochs: 100, F1 Macro: 0.1254
# 1/1 [==============================] - 0s 82ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [64, 32], Epochs: 200, F1 Macro: 0.4318
# 1/1 [==============================] - 0s 118ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [128, 64, 32], Epochs: 10, F1 Macro: 0.3317
# 1/1 [==============================] - 0s 152ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [128, 64, 32], Epochs: 50, F1 Macro: 0.4056
# 1/1 [==============================] - 0s 117ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [128, 64, 32], Epochs: 100, F1 Macro: 0.2424
# 1/1 [==============================] - 0s 111ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [128, 64, 32], Epochs: 200, F1 Macro: 0.5960
# 1/1 [==============================] - 0s 82ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [256, 128, 64], Epochs: 10, F1 Macro: 0.5084
# 1/1 [==============================] - 0s 80ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [256, 128, 64], Epochs: 50, F1 Macro: 0.1816
# 1/1 [==============================] - 0s 81ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [256, 128, 64], Epochs: 100, F1 Macro: 0.2818
# 1/1 [==============================] - 0s 94ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [256, 128, 64], Epochs: 200, F1 Macro: 0.5000
# 1/1 [==============================] - 0s 103ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [64, 64, 32], Epochs: 10, F1 Macro: 0.0846
# 1/1 [==============================] - 0s 114ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [64, 64, 32], Epochs: 50, F1 Macro: 0.2222
# 1/1 [==============================] - 0s 173ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [64, 64, 32], Epochs: 100, F1 Macro: 0.3152
# 1/1 [==============================] - 0s 177ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [64, 64, 32], Epochs: 200, F1 Macro: 0.2987
# 1/1 [==============================] - 0s 128ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [128, 64, 16], Epochs: 10, F1 Macro: 0.1212
# 1/1 [==============================] - 0s 185ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [128, 64, 16], Epochs: 50, F1 Macro: 0.2733
# 1/1 [==============================] - 0s 126ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [128, 64, 16], Epochs: 100, F1 Macro: 0.1538
# 1/1 [==============================] - 0s 85ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 64, Arquitectura: [128, 64, 16], Epochs: 200, F1 Macro: 0.3580
# 1/1 [==============================] - 0s 94ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [32], Epochs: 10, F1 Macro: 0.2088
# 1/1 [==============================] - 0s 63ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [32], Epochs: 50, F1 Macro: 0.1789
# 1/1 [==============================] - 0s 48ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [32], Epochs: 100, F1 Macro: 0.0238
# 1/1 [==============================] - 0s 69ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [32], Epochs: 200, F1 Macro: 0.0860
# 1/1 [==============================] - 0s 91ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [64], Epochs: 10, F1 Macro: 0.0769
# 1/1 [==============================] - 0s 116ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [64], Epochs: 50, F1 Macro: 0.2299
# 1/1 [==============================] - 0s 98ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [64], Epochs: 100, F1 Macro: 0.2014
# 1/1 [==============================] - 0s 97ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [64], Epochs: 200, F1 Macro: 0.4260
# 1/1 [==============================] - 0s 114ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [128], Epochs: 10, F1 Macro: 0.4079
# 1/1 [==============================] - 0s 81ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [128], Epochs: 50, F1 Macro: 0.3726
# 1/1 [==============================] - 0s 89ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [128], Epochs: 100, F1 Macro: 0.4905
# 1/1 [==============================] - 0s 110ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [128], Epochs: 200, F1 Macro: 0.2185
# 1/1 [==============================] - 0s 126ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [64, 32], Epochs: 10, F1 Macro: 0.1010
# 1/1 [==============================] - 0s 125ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [64, 32], Epochs: 50, F1 Macro: 0.0852
# 1/1 [==============================] - 0s 137ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [64, 32], Epochs: 100, F1 Macro: 0.2393
# 1/1 [==============================] - 0s 92ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [64, 32], Epochs: 200, F1 Macro: 0.2302
# 1/1 [==============================] - 0s 128ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [128, 64, 32], Epochs: 10, F1 Macro: 0.2664
# 1/1 [==============================] - 0s 103ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [128, 64, 32], Epochs: 50, F1 Macro: 0.2498
# 1/1 [==============================] - 0s 122ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [128, 64, 32], Epochs: 100, F1 Macro: 0.1641
# 1/1 [==============================] - 0s 125ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [128, 64, 32], Epochs: 200, F1 Macro: 0.3143
# 1/1 [==============================] - 0s 162ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [256, 128, 64], Epochs: 10, F1 Macro: 0.3095
# 1/1 [==============================] - 0s 138ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [256, 128, 64], Epochs: 50, F1 Macro: 0.3935
# 1/1 [==============================] - 0s 101ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [256, 128, 64], Epochs: 100, F1 Macro: 0.2481
# 1/1 [==============================] - 0s 91ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [256, 128, 64], Epochs: 200, F1 Macro: 0.3314
# 1/1 [==============================] - 0s 100ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [64, 64, 32], Epochs: 10, F1 Macro: 0.2564
# 1/1 [==============================] - 0s 117ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [64, 64, 32], Epochs: 50, F1 Macro: 0.1042
# 1/1 [==============================] - 0s 100ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [64, 64, 32], Epochs: 100, F1 Macro: 0.1919
# 1/1 [==============================] - 0s 130ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [64, 64, 32], Epochs: 200, F1 Macro: 0.3196
# 1/1 [==============================] - 0s 110ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [128, 64, 16], Epochs: 10, F1 Macro: 0.2000
# 1/1 [==============================] - 0s 107ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [128, 64, 16], Epochs: 50, F1 Macro: 0.2286
# 1/1 [==============================] - 0s 87ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [128, 64, 16], Epochs: 100, F1 Macro: 0.6185
# 1/1 [==============================] - 0s 79ms/step
# Tasa de aprendizaje: 1e-05, Tamaño de lote: 128, Arquitectura: [128, 64, 16], Epochs: 200, F1 Macro: 0.3717
# 1/1 [==============================] - 0s 76ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [32], Epochs: 10, F1 Macro: 0.1462
# 1/1 [==============================] - 0s 47ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [32], Epochs: 50, F1 Macro: 0.5011
# 1/1 [==============================] - 0s 44ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [32], Epochs: 100, F1 Macro: 0.6227
# 1/1 [==============================] - 0s 51ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [32], Epochs: 200, F1 Macro: 0.6782
# 1/1 [==============================] - 0s 75ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [64], Epochs: 10, F1 Macro: 0.2326
# 1/1 [==============================] - 0s 78ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [64], Epochs: 50, F1 Macro: 0.4314
# 1/1 [==============================] - 0s 49ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [64], Epochs: 100, F1 Macro: 0.5011
# 1/1 [==============================] - 0s 32ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [64], Epochs: 200, F1 Macro: 0.7138
# 1/1 [==============================] - 0s 34ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [128], Epochs: 10, F1 Macro: 0.5051
# 1/1 [==============================] - 0s 51ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [128], Epochs: 50, F1 Macro: 0.5900
# 1/1 [==============================] - 0s 69ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [128], Epochs: 100, F1 Macro: 0.7138
# 1/1 [==============================] - 0s 47ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [128], Epochs: 200, F1 Macro: 0.7138
# 1/1 [==============================] - 0s 34ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [64, 32], Epochs: 10, F1 Macro: 0.4577
# 1/1 [==============================] - 0s 47ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [64, 32], Epochs: 50, F1 Macro: 0.7432
# 1/1 [==============================] - 0s 36ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [64, 32], Epochs: 100, F1 Macro: 0.5230
# 1/1 [==============================] - 0s 47ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [64, 32], Epochs: 200, F1 Macro: 0.7138
# 1/1 [==============================] - 0s 68ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [128, 64, 32], Epochs: 10, F1 Macro: 0.5940
# 1/1 [==============================] - 0s 79ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [128, 64, 32], Epochs: 50, F1 Macro: 0.8399
# 1/1 [==============================] - 0s 71ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [128, 64, 32], Epochs: 100, F1 Macro: 0.8755
# 1/1 [==============================] - 0s 63ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [128, 64, 32], Epochs: 200, F1 Macro: 0.9052
# 1/1 [==============================] - 0s 95ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [256, 128, 64], Epochs: 10, F1 Macro: 0.7753
# 1/1 [==============================] - 0s 47ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [256, 128, 64], Epochs: 50, F1 Macro: 0.8125
# 1/1 [==============================] - 0s 79ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [256, 128, 64], Epochs: 100, F1 Macro: 0.9052
# 1/1 [==============================] - 0s 48ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [256, 128, 64], Epochs: 200, F1 Macro: 0.8474
# 1/1 [==============================] - 0s 79ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [64, 64, 32], Epochs: 10, F1 Macro: 0.6552
# 1/1 [==============================] - 0s 47ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [64, 64, 32], Epochs: 50, F1 Macro: 0.4345
# 1/1 [==============================] - 0s 45ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [64, 64, 32], Epochs: 100, F1 Macro: 0.7864
# 1/1 [==============================] - 0s 56ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [64, 64, 32], Epochs: 200, F1 Macro: 0.8755
# 1/1 [==============================] - 0s 71ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [128, 64, 16], Epochs: 10, F1 Macro: 0.4858
# 1/1 [==============================] - 0s 108ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [128, 64, 16], Epochs: 50, F1 Macro: 0.6674
# 1/1 [==============================] - 0s 47ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [128, 64, 16], Epochs: 100, F1 Macro: 0.7864
# 1/1 [==============================] - 0s 63ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 8, Arquitectura: [128, 64, 16], Epochs: 200, F1 Macro: 0.8755
# 1/1 [==============================] - 0s 46ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [32], Epochs: 10, F1 Macro: 0.2738
# 1/1 [==============================] - 0s 67ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [32], Epochs: 50, F1 Macro: 0.5203
# 1/1 [==============================] - 0s 32ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [32], Epochs: 100, F1 Macro: 0.2735
# 1/1 [==============================] - 0s 32ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [32], Epochs: 200, F1 Macro: 0.6190
# 1/1 [==============================] - 0s 63ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [64], Epochs: 10, F1 Macro: 0.5279
# 1/1 [==============================] - 0s 63ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [64], Epochs: 50, F1 Macro: 0.4671
# 1/1 [==============================] - 0s 51ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [64], Epochs: 100, F1 Macro: 0.6227
# 1/1 [==============================] - 0s 40ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [64], Epochs: 200, F1 Macro: 0.7138
# 1/1 [==============================] - 0s 64ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [128], Epochs: 10, F1 Macro: 0.3762
# 1/1 [==============================] - 0s 63ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [128], Epochs: 50, F1 Macro: 0.4706
# 1/1 [==============================] - 0s 94ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [128], Epochs: 100, F1 Macro: 0.7383
# 1/1 [==============================] - 0s 32ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [128], Epochs: 200, F1 Macro: 0.7138
# 1/1 [==============================] - 0s 48ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [64, 32], Epochs: 10, F1 Macro: 0.1852
# 1/1 [==============================] - 0s 79ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [64, 32], Epochs: 50, F1 Macro: 0.3772
# 1/1 [==============================] - 0s 94ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [64, 32], Epochs: 100, F1 Macro: 0.7138
# 1/1 [==============================] - 0s 70ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [64, 32], Epochs: 200, F1 Macro: 0.7383
# 1/1 [==============================] - 0s 63ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [128, 64, 32], Epochs: 10, F1 Macro: 0.3110
# 1/1 [==============================] - 0s 59ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [128, 64, 32], Epochs: 50, F1 Macro: 0.6053
# 1/1 [==============================] - 0s 63ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [128, 64, 32], Epochs: 100, F1 Macro: 0.7864
# 1/1 [==============================] - 0s 71ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [128, 64, 32], Epochs: 200, F1 Macro: 0.8755
# 1/1 [==============================] - 0s 78ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [256, 128, 64], Epochs: 10, F1 Macro: 0.4231
# 1/1 [==============================] - 0s 60ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [256, 128, 64], Epochs: 50, F1 Macro: 0.7744
# 1/1 [==============================] - 0s 47ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [256, 128, 64], Epochs: 100, F1 Macro: 0.8755
# 1/1 [==============================] - 0s 62ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [256, 128, 64], Epochs: 200, F1 Macro: 0.8664
# 1/1 [==============================] - 0s 49ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [64, 64, 32], Epochs: 10, F1 Macro: 0.4848
# 1/1 [==============================] - 0s 77ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [64, 64, 32], Epochs: 50, F1 Macro: 0.4706
# 1/1 [==============================] - 0s 56ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [64, 64, 32], Epochs: 100, F1 Macro: 0.8474
# 1/1 [==============================] - 0s 63ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [64, 64, 32], Epochs: 200, F1 Macro: 0.8374
# 1/1 [==============================] - 0s 77ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [128, 64, 16], Epochs: 10, F1 Macro: 0.5102
# 1/1 [==============================] - 0s 35ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [128, 64, 16], Epochs: 50, F1 Macro: 0.4680
# 1/1 [==============================] - 0s 110ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [128, 64, 16], Epochs: 100, F1 Macro: 0.7138
# 1/1 [==============================] - 0s 75ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 16, Arquitectura: [128, 64, 16], Epochs: 200, F1 Macro: 0.9052
# 1/1 [==============================] - 0s 63ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 32, Arquitectura: [32], Epochs: 10, F1 Macro: 0.2854
# 1/1 [==============================] - 0s 53ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 32, Arquitectura: [32], Epochs: 50, F1 Macro: 0.3867
# 1/1 [==============================] - 0s 68ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 32, Arquitectura: [32], Epochs: 100, F1 Macro: 0.3017
# 1/1 [==============================] - 0s 101ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 32, Arquitectura: [32], Epochs: 200, F1 Macro: 0.5794
# 1/1 [==============================] - 0s 123ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 32, Arquitectura: [64], Epochs: 10, F1 Macro: 0.3460
# 1/1 [==============================] - 0s 86ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 32, Arquitectura: [64], Epochs: 50, F1 Macro: 0.4680
# 1/1 [==============================] - 0s 96ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 32, Arquitectura: [64], Epochs: 100, F1 Macro: 0.5660
# 1/1 [==============================] - 0s 85ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 32, Arquitectura: [64], Epochs: 200, F1 Macro: 0.7138
# 1/1 [==============================] - 0s 94ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 32, Arquitectura: [128], Epochs: 10, F1 Macro: 0.6077
# 1/1 [==============================] - 0s 73ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 32, Arquitectura: [128], Epochs: 50, F1 Macro: 0.3333
# 1/1 [==============================] - 0s 80ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 32, Arquitectura: [128], Epochs: 100, F1 Macro: 0.5011
# 1/1 [==============================] - 0s 70ms/step
# Tasa de aprendizaje: 0.0001, Tamaño de lote: 32, Arquitectura: [128], Epochs: 200, F1 Macro: 0.7138
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 7
#       5 # Iterar sobre todas las combinaciones de hiperparámetros
#       6 for lr, bs, arch, ep in param_grid:
# ----> 7     f1_macro = train_and_evaluate_model(
#       8         learning_rate=lr,
#       9         batch_size=bs,
#      10         architecture=arch,
#      11         epochs=ep,
#      12         input_dim=input_dim,
#      13         X_train=X_train,
#      14         y_train=y_train,
#      15         X_test=X_test,
#      16         y_test=y_test
#      17     )
#      18     # Registrar el resultado
#      19     results.append({
#      20         'learning_rate': lr,
#      21         'batch_size': bs,
#    (...)
#      24         'f1_macro': f1_macro
#      25     })
#
# Cell In[18], line 5, in train_and_evaluate_model(learning_rate, batch_size, architecture, epochs, input_dim, X_train, y_train, X_test, y_test)
#       3 model = create_model(learning_rate=learning_rate, architecture=architecture, input_dim=input_dim)
#       4 # Entrenar el modelo
# ----> 5 model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=0)
#       6 # Realizar predicciones en el conjunto de prueba
#       7 y_pred_prob = model.predict(X_test)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\training.py:1590, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1580     self._cluster_coordinator = (
#    1581         tf.distribute.experimental.coordinator.ClusterCoordinator(
#    1582             self.distribute_strategy
#    1583         )
#    1584     )
#    1586 with self.distribute_strategy.scope(), training_utils.RespectCompiledTrainableState(  # noqa: E501
#    1587     self
#    1588 ):
#    1589     # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1590     data_handler = data_adapter.get_data_handler(
#    1591         x=x,
#    1592         y=y,
#    1593         sample_weight=sample_weight,
#    1594         batch_size=batch_size,
#    1595         steps_per_epoch=steps_per_epoch,
#    1596         initial_epoch=initial_epoch,
#    1597         epochs=epochs,
#    1598         shuffle=shuffle,
#    1599         class_weight=class_weight,
#    1600         max_queue_size=max_queue_size,
#    1601         workers=workers,
#    1602         use_multiprocessing=use_multiprocessing,
#    1603         model=self,
#    1604         steps_per_execution=self._steps_per_execution,
#    1605     )
#    1607     # Container that configures and calls `tf.keras.Callback`s.
#    1608     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py:1579, in get_data_handler(*args, **kwargs)
#    1577 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1578     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1579 return DataHandler(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py:1259, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1256     self._steps_per_execution = steps_per_execution
#    1258 adapter_cls = select_data_adapter(x, y)
# -> 1259 self._adapter = adapter_cls(
#    1260     x,
#    1261     y,
#    1262     batch_size=batch_size,
#    1263     steps=steps_per_epoch,
#    1264     epochs=epochs - initial_epoch,
#    1265     sample_weights=sample_weight,
#    1266     shuffle=shuffle,
#    1267     max_queue_size=max_queue_size,
#    1268     workers=workers,
#    1269     use_multiprocessing=use_multiprocessing,
#    1270     distribution_strategy=tf.distribute.get_strategy(),
#    1271     model=model,
#    1272 )
#    1274 strategy = tf.distribute.get_strategy()
#    1276 self._current_step = 0
#
# File ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py:345, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     342         flat_dataset = flat_dataset.shuffle(1024).repeat(epochs)
#     343     return flat_dataset
# --> 345 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     347 dataset = self.slice_inputs(indices_dataset, inputs)
#     349 if shuffle == "batch":
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2337, in DatasetV2.flat_map(self, map_func, name)
#    2304 def flat_map(self, map_func, name=None):
#    2305   """Maps `map_func` across this dataset and flattens the result.
#    2306
#    2307   The type signature is:
#    (...)
#    2335     A new `Dataset` with the transformation applied as described above.
#    2336   """
# -> 2337   return FlatMapDataset(self, map_func, name=name)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:5583, in FlatMapDataset.__init__(self, input_dataset, map_func, name)
#    5581 """See `Dataset.flat_map()` for details."""
#    5582 self._input_dataset = input_dataset
# -> 5583 self._map_func = structured_function.StructuredFunctionWrapper(
#    5584     map_func, self._transformation_name(), dataset=input_dataset)
#    5585 if not isinstance(self._map_func.output_structure, DatasetSpec):
#    5586   raise TypeError(
#    5587       "The `map_func` argument must return a `Dataset` object. Got "
#    5588       f"{_get_type(self._map_func.output_structure)!r}.")
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\structured_function.py:263, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     256       warnings.warn(
#     257           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     258           "option is set, this option does not apply to tf.data functions. "
#     259           "To force eager execution of tf.data functions, please use "
#     260           "`tf.data.experimental.enable_debug_mode()`.")
#     261     fn_factory = trace_tf_function(defun_kwargs)
# --> 263 self._function = fn_factory()
#     264 # There is no graph to add in eager mode.
#     265 add_to_graph &= not context.executing_eagerly()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:226, in TracingCompiler.get_concrete_function(self, *args, **kwargs)
#     217 def get_concrete_function(self, *args, **kwargs):
#     218   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#     219
#     220   Args:
#    (...)
#     224       `tf.Tensor` or `tf.TensorSpec`.
#     225   """
# --> 226   concrete_function = self._get_concrete_function_garbage_collected(
#     227       *args, **kwargs)
#     228   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#     229   return concrete_function
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:192, in TracingCompiler._get_concrete_function_garbage_collected(self, *args, **kwargs)
#     189   self._function_spec.validate_inputs_with_signature(args, kwargs)
#     191 with self._lock:
# --> 192   concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     193   seen_names = set()
#     194   captured = object_identity.ObjectIdentitySet(
#     195       concrete_function.graph.internal_captures)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:157, in TracingCompiler._maybe_define_concrete_function(self, args, kwargs)
#     154   args = self.input_signature
#     155   kwargs = {}
# --> 157 return self._maybe_define_function(args, kwargs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:360, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     357   # Only get placeholders for arguments, not captures
#     358   args, kwargs = generalized_func_key._placeholder_value()  # pylint: disable=protected-access
# --> 360 concrete_function = self._create_concrete_function(args, kwargs)
#     362 graph_capture_container = concrete_function.graph._capture_func_lib  # pylint: disable=protected-access
#     363 # Maintain the list of all captures
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:284, in TracingCompiler._create_concrete_function(self, args, kwargs)
#     279 missing_arg_names = [
#     280     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#     281 ]
#     282 arg_names = base_arg_names + missing_arg_names
#     283 concrete_function = monomorphic_function.ConcreteFunction(
# --> 284     func_graph_module.func_graph_from_py_func(
#     285         self._name,
#     286         self._python_function,
#     287         args,
#     288         kwargs,
#     289         None,
#     290         autograph=self._autograph,
#     291         autograph_options=self._autograph_options,
#     292         arg_names=arg_names,
#     293         capture_by_value=self._capture_by_value),
#     294     self._function_attributes,
#     295     spec=self.function_spec,
#     296     # Tell the ConcreteFunction to clean up its graph once it goes out of
#     297     # scope. This is not the default behavior since it gets used in some
#     298     # places (like Keras) where the FuncGraph lives longer than the
#     299     # ConcreteFunction.
#     300     shared_func_graph=False)
#     301 return concrete_function
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py:1283, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1280 else:
#    1281   _, original_func = tf_decorator.unwrap(python_func)
# -> 1283 func_outputs = python_func(*func_args, **func_kwargs)
#    1285 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1286 # TensorArrays and `None`s.
#    1287 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\structured_function.py:240, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     234 @eager_function.defun_with_attributes(
#     235     input_signature=structure.get_flat_tensor_specs(
#     236         self._input_structure),
#     237     autograph=False,
#     238     attributes=defun_kwargs)
#     239 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 240   ret = wrapper_helper(*args)
#     241   ret = structure.to_tensor_list(self._output_structure, ret)
#     242   return [ops.convert_to_tensor(t) for t in ret]
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\structured_function.py:171, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     169 if not _should_unpack(nested_args):
#     170   nested_args = (nested_args,)
# --> 171 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     172 ret = variable_utils.convert_variables_to_tensors(ret)
#     173 if _should_pack(ret):
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py:326, in TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices(indices)
#     309 """Convert a Tensor of indices into a dataset of batched indices.
#     310
#     311 This step can be accomplished in several ways. The most natural is
#    (...)
#     323   A Dataset of batched indices.
#     324 """
#     325 num_in_full_batch = num_full_batches * batch_size
# --> 326 first_k_indices = tf.slice(indices, [0], [num_in_full_batch])
#     327 first_k_indices = tf.reshape(
#     328     first_k_indices, [num_full_batches, batch_size]
#     329 )
#     331 flat_dataset = tf.data.Dataset.from_tensor_slices(first_k_indices)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py:1163, in slice(input_, begin, size, name)
#    1111 @tf_export("slice")
#    1112 @dispatch.add_dispatch_support
#    1113 def slice(input_, begin, size, name=None):
#    1114   # pylint: disable=redefined-builtin
#    1115   """Extracts a slice from a tensor.
#    1116
#    1117   See also `tf.strided_slice`.
#    (...)
#    1161     A `Tensor` the same type as `input_`.
#    1162   """
# -> 1163   return gen_array_ops._slice(input_, begin, size, name=name)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:11915, in _slice(input, begin, size, name)
#   11913     pass  # Add nodes to the TensorFlow graph.
#   11914 # Add nodes to the TensorFlow graph.
# > 11915 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   11916       "Slice", input=input, begin=begin, size=size, name=name)
#   11917 _result = _outputs[:]
#   11918 if _execute.must_record_gradient():
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:777, in _apply_op_helper(op_type_name, name, **keywords)
#     775 with g.as_default(), ops.name_scope(name) as scope:
#     776   if fallback:
# --> 777     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     778                            keywords, default_type_attr_map, attrs, inputs,
#     779                            input_types)
#     780     _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     781                            default_type_attr_map, attrs)
#     782     _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:550, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     544       values = ops.convert_to_tensor(
#     545           values,
#     546           name=input_arg.name,
#     547           as_ref=input_arg.is_ref,
#     548           preferred_dtype=default_dtype)
#     549   else:
# --> 550     values = ops.convert_to_tensor(
#     551         values,
#     552         name=input_arg.name,
#     553         dtype=dtype,
#     554         as_ref=input_arg.is_ref,
#     555         preferred_dtype=default_dtype)
#     556 except TypeError as err:
#     557   if dtype is None:
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:1636, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1627       raise RuntimeError(
#    1628           _add_error_prefix(
#    1629               f"Conversion function {conversion_func!r} for type "
#    (...)
#    1632               f"actual = {ret.dtype.base_dtype.name}",
#    1633               name=name))
#    1635 if ret is None:
# -> 1636   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1638 if ret is NotImplemented:
#    1639   continue
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py:343, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     340 def _constant_tensor_conversion_function(v, dtype=None, name=None,
#     341                                          as_ref=False):
#     342   _ = as_ref
# --> 343   return constant(v, dtype=dtype, name=name)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py:267, in constant(value, dtype, shape, name)
#     170 @tf_export("constant", v1=[])
#     171 def constant(value, dtype=None, shape=None, name="Const"):
#     172   """Creates a constant tensor from a tensor-like object.
#     173
#     174   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     265     ValueError: if called on a symbolic tensor.
#     266   """
# --> 267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     268                         allow_broadcast=True)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py:289, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     287 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     288 attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 289 const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     290     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     292 if op_callbacks.should_invoke_op_callbacks():
#     293   # TODO(b/147670703): Once the special-op creation code paths
#     294   # are unified. Remove this `if` block.
#     295   callback_outputs = op_callbacks.invoke_op_callbacks(
#     296       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py:749, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     747   inp = self.capture(inp)
#     748   captured_inputs.append(inp)
# --> 749 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     750     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     751     compute_device)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:3798, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3795 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3796 # Session.run call cannot occur between creating and mutating the op.
#    3797 with self._mutation_lock():
# -> 3798   ret = Operation(
#    3799       node_def,
#    3800       self,
#    3801       inputs=inputs,
#    3802       output_types=dtypes,
#    3803       control_inputs=control_inputs,
#    3804       input_types=input_types,
#    3805       original_op=self._default_original_op,
#    3806       op_def=op_def)
#    3807   self._create_op_helper(ret, compute_device=compute_device)
#    3808 return ret
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:2106, in Operation.__init__(***failed resolving arguments***)
#    2103     control_input_ops.append(control_op)
#    2105 # Initialize c_op from node_def and other inputs
# -> 2106 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    2107 self._init_from_c_op(c_op=c_op, g=g)
#    2109 self._original_op = original_op
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:1964, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1960   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1961                                          serialized)
#    1963 try:
# -> 1964   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1965 except errors.InvalidArgumentError as e:
#    1966   # Convert to ValueError for backwards compatibility.
#    1967   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %%
results_df = pd.DataFrame(results)

# Encontrar la mejor configuración
best_result = results_df.loc[results_df['f1_macro'].idxmax()]
print("\nMejor Configuración de Hiperparámetros:")
print(f"Tasa de Aprendizaje: {best_result['learning_rate']}")
print(f"Tamaño de Lote: {best_result['batch_size']}")
print(f"Arquitectura: {best_result['architecture']}")
print(f"Épocas: {best_result['epochs']}")
print(f"Mejor F1 Macro Score: {best_result['f1_macro']:.4f}")
# Out:
# Mejor Configuración de Hiperparámetros:
# Tasa de Aprendizaje: 0.001
# Tamaño de Lote: 16
# Arquitectura: [64, 32]
# Épocas: 100
# Mejor F1 Macro Score: 0.9052

# %% [markdown]
# ### 3.1 Brief discussion of the experimental procedure, along with the results obtained

# %% [markdown]
# ...

# %% [markdown]
# ### 3.2 Estimate model performance with the validation set

# %%
X_full = pd.concat([X_train, X_test], axis=0).reset_index(drop=True)
y_full = pd.concat([y_train, y_test], axis=0).reset_index(drop=True)

y_full_labels = np.argmax(y_full.values, axis=1)

# %%
X_full_values = X_full.values
y_full_values = y_full.values  # Etiquetas one-hot encoding
y_full_labels = np.argmax(y_full_values, axis=1)  # Etiquetas categóricas

# Definir las clases
class_names = ['ASTROCYTOMA', 'GLIOBLASTOMA', 'MENINGIOMA']

# Configurar la validación cruzada
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Almacenar las métricas
precision_scores = []
recall_scores = []
f1_scores = []
auc_scores = []

for train_index, val_index in skf.split(X_full_values, y_full_labels):
    X_train_cv, X_val_cv = X_full_values[train_index], X_full_values[val_index]
    y_train_cv, y_val_cv = y_full_values[train_index], y_full_values[val_index]
    y_val_labels = y_full_labels[val_index]
    
    # Crear y compilar el modelo
    model_cv = create_model(
        learning_rate=best_result['learning_rate'],
        architecture=best_result['architecture'],
        input_dim=X_full_values.shape[1]
    )
    
    # Entrenar el modelo
    model_cv.fit(
        X_train_cv,
        y_train_cv,
        batch_size=best_result['batch_size'],
        epochs=int(best_result['epochs']),
        verbose=0
    )
    
    # Predecir las probabilidades
    y_pred_prob = model_cv.predict(X_val_cv)
    y_pred_labels = np.argmax(y_pred_prob, axis=1)
    
    # Calcular las métricas
    precision, recall, f1, _ = precision_recall_fscore_support(y_val_labels, y_pred_labels, average=None, labels=[0,1,2])
    precision_scores.append(precision)
    recall_scores.append(recall)
    f1_scores.append(f1)
    
    # Calcular AUC para cada clase
    y_val_binarized = y_val_cv  # Ya en formato one-hot
    auc = roc_auc_score(y_val_binarized, y_pred_prob, average=None, multi_class='ovr')
    auc_scores.append(auc)

# Promediar las métricas a través de las iteraciones
mean_precision = np.mean(precision_scores, axis=0)
mean_recall = np.mean(recall_scores, axis=0)
mean_f1 = np.mean(f1_scores, axis=0)
mean_auc = np.mean(auc_scores, axis=0)

# Mostrar las métricas para cada clase
for idx, class_name in enumerate(class_names):
    print(f"\nMétricas para {class_name}:")
    print(f"Precisión: {mean_precision[idx]:.4f}")
    print(f"Recall: {mean_recall[idx]:.4f}")
    print(f"F1-Score: {mean_f1[idx]:.4f}")
    print(f"AUC: {mean_auc[idx]:.4f}")
# Out:
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
#
# Métricas para ASTROCYTOMA:
# Precisión: 0.6000
# Recall: 0.6300
# F1-Score: 0.6122
# AUC: 0.8586
#
# Métricas para GLIOBLASTOMA:
# Precisión: 0.7533
# Recall: 0.7500
# F1-Score: 0.7348
# AUC: 0.8833
#
# Métricas para MENINGIOMA:
# Precisión: 0.8188
# Recall: 0.8055
# F1-Score: 0.8087
# AUC: 0.8745

# %% [markdown]
# ### 3.3 Retrain your model with the whole training data, considering the best hyperparams set

# %%
best_model = create_model(
    learning_rate=best_result['learning_rate'],
    architecture=best_result['architecture'],
    input_dim=input_dim
)

best_model.fit(
    X_train,
    y_train,
    batch_size=best_result['batch_size'],
    epochs=int(best_result['epochs']),
    verbose=0
)

# Evaluar el mejor modelo
y_pred_prob = best_model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_true = np.argmax(y_test, axis=1)
f1_macro = f1_score(y_true, y_pred, average='macro')

print(f"\nF1 Macro Score del Mejor Modelo Reentrenado: {f1_macro:.4f}")

# Reporte de clasificación detallado

print("\nReporte de Clasificación para el Mejor Modelo:")
print(classification_report(y_true, y_pred, target_names=label_mapping.keys()))
# Out:
# 1/1 [==============================] - 0s 58ms/step
#
# F1 Macro Score del Mejor Modelo Reentrenado: 0.8755
#
# Reporte de Clasificación para el Mejor Modelo:
#               precision    recall  f1-score   support
#
#  ASTROCYTOMA       0.75      0.86      0.80         7
# GLIOBLASTOMA       1.00      0.80      0.89         5
#   MENINGIOMA       0.94      0.94      0.94        16
#
#     accuracy                           0.89        28
#    macro avg       0.90      0.86      0.88        28
# weighted avg       0.90      0.89      0.89        28

# %%
loss = best_model
3.history['loss']

# Crear la figura
plt.figure(figsize=(8,6))
plt.plot(loss, label='Pérdida de Entrenamiento', color='blue')
plt.title('Pérdida de Entrenamiento a lo largo de las Épocas')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()
plt.grid(True)
plt.show()

# %%
best_model.save('mejor_modelo.h5')

# %% [markdown]
# # Block III. Clinical decision support system deployment
